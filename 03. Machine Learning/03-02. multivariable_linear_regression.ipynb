# %% [markdown]
# ## 2. 파이토치로 구현하기

# %%
import torch
import torch.optim as optim
print(f'PyTorch version: {torch.__version__}')
torch.manual_seed(1)
# Out:
# PyTorch version: 2.9.1+cu128

# %%
# 훈련 데이터
x1_train = torch.FloatTensor([[73], [93], [89], [96], [73]])
x2_train = torch.FloatTensor([[80], [88], [91], [98], [66]])
x3_train = torch.FloatTensor([[75], [93], [90], [100], [70]])
y_train = torch.FloatTensor([[152], [185], [180], [196], [142]])

# %%
# 가중치 w와 편향 b 초기화
w1 = torch.zeros(1, requires_grad=True)
w2 = torch.zeros(1, requires_grad=True)
w3 = torch.zeros(1, requires_grad=True)
b = torch.zeros(1, requires_grad=True)

# %%
# optimizer 설정
optimizer = optim.SGD([w1, w2, w3, b], lr=1e-5)

nb_epochs = 10000
for epoch in range(nb_epochs + 1):

    # H(x) 계산
    hypothesis = x1_train * w1 + x2_train * w2 + x3_train * w3 + b

    # cost 계산
    cost = torch.mean((hypothesis - y_train) ** 2)

    # cost로 H(x) 개선
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()

    # 100번마다 로그 출력
    if epoch % 100 == 0:
        print('Epoch {:4d}/{} w1: {:.3f} w2: {:.3f} w3: {:.3f} b: {:.3f} Cost: {:.6f}'.format(
            epoch, nb_epochs, w1.item(), w2.item(), w3.item(), b.item(), cost.item()
        ))
# Out:
# Epoch    0/10000 w1: 0.294 w2: 0.294 w3: 0.297 b: 0.003 Cost: 29661.800781
# Epoch  100/10000 w1: 0.674 w2: 0.661 w3: 0.676 b: 0.008 Cost: 1.563628
# Epoch  200/10000 w1: 0.679 w2: 0.655 w3: 0.677 b: 0.008 Cost: 1.497595
# Epoch  300/10000 w1: 0.684 w2: 0.649 w3: 0.677 b: 0.008 Cost: 1.435044
# Epoch  400/10000 w1: 0.689 w2: 0.643 w3: 0.678 b: 0.008 Cost: 1.375726
# Epoch  500/10000 w1: 0.694 w2: 0.638 w3: 0.678 b: 0.009 Cost: 1.319507
# Epoch  600/10000 w1: 0.699 w2: 0.633 w3: 0.679 b: 0.009 Cost: 1.266222
# Epoch  700/10000 w1: 0.704 w2: 0.627 w3: 0.679 b: 0.009 Cost: 1.215703
# Epoch  800/10000 w1: 0.709 w2: 0.622 w3: 0.679 b: 0.009 Cost: 1.167810
# Epoch  900/10000 w1: 0.713 w2: 0.617 w3: 0.680 b: 0.009 Cost: 1.122429
# Epoch 1000/10000 w1: 0.718 w2: 0.613 w3: 0.680 b: 0.009 Cost: 1.079390
# Epoch 1100/10000 w1: 0.722 w2: 0.608 w3: 0.680 b: 0.009 Cost: 1.038574
# Epoch 1200/10000 w1: 0.727 w2: 0.603 w3: 0.681 b: 0.010 Cost: 0.999884
# ...

# %% [markdown]
# ## 4. 행렬 연산을 고려하여 파이토치로 구현하기

# %%
x_train  =  torch.FloatTensor([[73,  80,  75],
                               [93,  88,  93],
                               [89,  91,  90],
                               [96,  98,  100],
                               [73,  66,  70]])
y_train  =  torch.FloatTensor([[152],  [185],  [180],  [196],  [142]])

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# torch.Size([5, 3])
# torch.Size([5, 1])

# %%
# 가중치와 편향 선언
W = torch.zeros((3, 1), requires_grad=True)
b = torch.zeros(1, requires_grad=True)

# %%
hypothesis = x_train.matmul(W) + b

# %%
x_train  =  torch.FloatTensor([[73,  80,  75],
                               [93,  88,  93],
                               [89,  91,  90],
                               [96,  98,  100],
                               [73,  66,  70]])
y_train  =  torch.FloatTensor([[152],  [185],  [180],  [196],  [142]])

# 모델 초기화
W = torch.zeros((3, 1), requires_grad=True)
b = torch.zeros(1, requires_grad=True)
# optimizer 설정
optimizer = optim.SGD([W, b], lr=1e-5)

nb_epochs = 10000
for epoch in range(nb_epochs + 1):

    # H(x) 계산
    # 편향 b는 브로드 캐스팅되어 각 샘플에 더해집니다.
    hypothesis = x_train.matmul(W) + b

    # cost 계산
    cost = torch.mean((hypothesis - y_train) ** 2)

    # cost로 H(x) 개선
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()

    print(f'Epoch {epoch:4d}/{nb_epochs} Weights: {W.squeeze().detach()} Cost: {cost.item():.6f}')
# Out:
# Epoch    0/10000 Weights: tensor([0.2940, 0.2936, 0.2974]) Cost: 29661.800781
# Epoch    1/10000 Weights: tensor([0.4586, 0.4579, 0.4639]) Cost: 9298.520508
# Epoch    2/10000 Weights: tensor([0.5508, 0.5499, 0.5571]) Cost: 2915.712402
# Epoch    3/10000 Weights: tensor([0.6025, 0.6014, 0.6093]) Cost: 915.040527
# Epoch    4/10000 Weights: tensor([0.6314, 0.6302, 0.6385]) Cost: 287.936096
# Epoch    5/10000 Weights: tensor([0.6476, 0.6463, 0.6549]) Cost: 91.371063
# Epoch    6/10000 Weights: tensor([0.6568, 0.6553, 0.6640]) Cost: 29.758249
# Epoch    7/10000 Weights: tensor([0.6619, 0.6603, 0.6692]) Cost: 10.445267
# Epoch    8/10000 Weights: tensor([0.6648, 0.6630, 0.6720]) Cost: 4.391237
# Epoch    9/10000 Weights: tensor([0.6664, 0.6646, 0.6737]) Cost: 2.493121
# Epoch   10/10000 Weights: tensor([0.6674, 0.6654, 0.6746]) Cost: 1.897688
# Epoch   11/10000 Weights: tensor([0.6679, 0.6658, 0.6751]) Cost: 1.710552
# ...

# %%
# 임의의 입력 값에 대한 예측
with torch.no_grad(): # 그래디언트 계산 비활성화
    new_input = torch.FloatTensor([[75, 85, 72]])  # 예측하고 싶은 임의의 입력
    prediction = new_input.matmul(W) + b
    print(f'Predicted value for input {new_input.squeeze().tolist()}: {prediction.item():.4f}')
    print(f'Weights: {[f"{w:.4f}" for w in W.squeeze().tolist()]}, Bias: {b.item():.4f}')
# Out:
# Predicted value for input [75.0, 85.0, 72.0]: 153.4807
# Weights: ['0.8881', '0.4642', '0.6582'], Bias: 0.0195
